# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ace7229bc6446b6a558b54a11efb9f9e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        country_code = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country" : country_code,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Descrption": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | san quintin
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | kloulklubed
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | ostrovnoy
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | charters towers
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | katsuura
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | quatre cocos
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | bani
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | vidim
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | manzanillo
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | madingou
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | cidreira
# Processing Record 32 of Set 1 | tornio
# Processing Record 33 of Set 1 | greeley
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | seoul
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | haifa
# Processing Record 38 of Set 1 | fortuna
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | muhlhausen
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | kavieng
# Processing Record 44 of Set 1 | kantemirovka
# Processing Record 45 of Set 1 | boralday
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | salinas
# Processing Record 1 of Set 2 | zyryanka
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | vestmannaeyjar
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | russell
# Processing Record 7 of Set 2 | kungurtug
# Processing Record 8 of Set 2 | banjar
# Processing Record 9 of Set 2 | bandarbeyla
# Processing Record 10 of Set 2 | acarau
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | asau
# Processing Record 13 of Set 2 | kununurra
# Processing Record 14 of Set 2 | chihuahua
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | touros
# Processing Record 17 of Set 2 | torbay
# Processing Record 18 of Set 2 | kampong thum
# Processing Record 19 of Set 2 | nioro
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | isangel
# Processing Record 22 of Set 2 | saint-michel-des-saints
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 2 | kochi
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | demyansk
# Processing Record 29 of Set 2 | mount gambier
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | itapirapua
# Processing Record 33 of Set 2 | kozmodemyansk
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | maltahohe
# Processing Record 36 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 2 | moose factory
# Processing Record 38 of Set 2 | manali
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | gat
# Processing Record 42 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 2 | kiunga
# Processing Record 44 of Set 2 | gamba
# Processing Record 45 of Set 2 | constitucion
# Processing Record 46 of Set 2 | itabira
# Processing Record 47 of Set 2 | pocone
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | rocha
# Processing Record 1 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 3 | hualmay
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | qandala
# Processing Record 5 of Set 3 | kasongo-lunda
# Processing Record 6 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 3 | luderitz
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | melilla
# Processing Record 11 of Set 3 | half moon bay
# Processing Record 12 of Set 3 | kalmunai
# Processing Record 13 of Set 3 | the valley
# Processing Record 14 of Set 3 | bam
# Processing Record 15 of Set 3 | pontianak
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | ancud
# Processing Record 19 of Set 3 | mahibadhoo
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | ifo
# Processing Record 22 of Set 3 | lompoc
# Processing Record 23 of Set 3 | moranbah
# Processing Record 24 of Set 3 | moba
# Processing Record 25 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 26 of Set 3 | henties bay
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | cabo san lucas
# Processing Record 29 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 3 | shu
# Processing Record 31 of Set 3 | tilichiki
# Processing Record 32 of Set 3 | geraldton
# Processing Record 33 of Set 3 | bengkulu
# Processing Record 34 of Set 3 | vao
# Processing Record 35 of Set 3 | kaeo
# Processing Record 36 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 3 | mpongwe
# Processing Record 38 of Set 3 | kiruna
# Processing Record 39 of Set 3 | alice springs
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | laguna
# Processing Record 43 of Set 3 | strasshof
# City not found. Skipping...
# Processing Record 44 of Set 3 | zharkent
# Processing Record 45 of Set 3 | msanga
# Processing Record 46 of Set 3 | provideniya
# Processing Record 47 of Set 3 | manjeshwar
# Processing Record 48 of Set 3 | damghan
# Processing Record 49 of Set 3 | upernavik
# Processing Record 50 of Set 3 | hirara
# Processing Record 1 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 4 | tessalit
# Processing Record 3 of Set 4 | lagoa
# Processing Record 4 of Set 4 | havre-saint-pierre
# Processing Record 5 of Set 4 | bathsheba
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | gastonia
# Processing Record 8 of Set 4 | ballina
# Processing Record 9 of Set 4 | marienburg
# Processing Record 10 of Set 4 | pisco
# Processing Record 11 of Set 4 | arkhangelsk
# Processing Record 12 of Set 4 | port blair
# Processing Record 13 of Set 4 | chaihe
# Processing Record 14 of Set 4 | petropavlovka
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | kochubey
# Processing Record 17 of Set 4 | piranhas
# Processing Record 18 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 4 | bonavista
# Processing Record 20 of Set 4 | salair
# Processing Record 21 of Set 4 | poum
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 4 | nouadhibou
# Processing Record 25 of Set 4 | mahebourg
# Processing Record 26 of Set 4 | capreol
# Processing Record 27 of Set 4 | laguna de perlas
# Processing Record 28 of Set 4 | warwick
# Processing Record 29 of Set 4 | virtsu
# Processing Record 30 of Set 4 | chulman
# Processing Record 31 of Set 4 | talnakh
# Processing Record 32 of Set 4 | komsomolets
# Processing Record 33 of Set 4 | boguchany
# Processing Record 34 of Set 4 | yebaishou
# Processing Record 35 of Set 4 | sungaipenuh
# Processing Record 36 of Set 4 | hami
# Processing Record 37 of Set 4 | pacific grove
# Processing Record 38 of Set 4 | ahipara
# Processing Record 39 of Set 4 | chernyshevskiy
# Processing Record 40 of Set 4 | tigil
# Processing Record 41 of Set 4 | alyangula
# Processing Record 42 of Set 4 | grottammare
# Processing Record 43 of Set 4 | kulhudhuffushi
# Processing Record 44 of Set 4 | iraray
# Processing Record 45 of Set 4 | camacha
# Processing Record 46 of Set 4 | randolph
# Processing Record 47 of Set 4 | palauig
# Processing Record 48 of Set 4 | bilibino
# Processing Record 49 of Set 4 | hare bay
# Processing Record 50 of Set 4 | bashtanka
# Processing Record 1 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 5 | carandai
# Processing Record 3 of Set 5 | hay river
# Processing Record 4 of Set 5 | eyl
# Processing Record 5 of Set 5 | churapcha
# Processing Record 6 of Set 5 | lunavada
# Processing Record 7 of Set 5 | okandja
# City not found. Skipping...
# Processing Record 8 of Set 5 | kearney
# Processing Record 9 of Set 5 | sistranda
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | kahului
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | dulce nombre de culmi
# Processing Record 14 of Set 5 | purpe
# Processing Record 15 of Set 5 | tasiilaq
# Processing Record 16 of Set 5 | santa cruz
# Processing Record 17 of Set 5 | cochabamba
# Processing Record 18 of Set 5 | kurmanayevka
# Processing Record 19 of Set 5 | marathon
# Processing Record 20 of Set 5 | guadalajara
# Processing Record 21 of Set 5 | tura
# Processing Record 22 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 5 | faya
# Processing Record 24 of Set 5 | nuuk
# Processing Record 25 of Set 5 | jinan
# Processing Record 26 of Set 5 | coihaique
# Processing Record 27 of Set 5 | stokmarknes
# Processing Record 28 of Set 5 | yagodnoye
# Processing Record 29 of Set 5 | mangai
# Processing Record 30 of Set 5 | korla
# Processing Record 31 of Set 5 | fairbanks
# Processing Record 32 of Set 5 | matara
# Processing Record 33 of Set 5 | dongkan
# Processing Record 34 of Set 5 | dudinka
# Processing Record 35 of Set 5 | rio gallegos
# Processing Record 36 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 5 | hambantota
# Processing Record 38 of Set 5 | la esperanza
# Processing Record 39 of Set 5 | puerto del rosario
# Processing Record 40 of Set 5 | saint-joseph
# Processing Record 41 of Set 5 | hobyo
# Processing Record 42 of Set 5 | cedar city
# Processing Record 43 of Set 5 | sitka
# Processing Record 44 of Set 5 | conner
# Processing Record 45 of Set 5 | lorengau
# Processing Record 46 of Set 5 | minggang
# Processing Record 47 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 5 | severo-kurilsk
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | beringovskiy
# Processing Record 1 of Set 6 | samarai
# Processing Record 2 of Set 6 | takoradi
# Processing Record 3 of Set 6 | castro
# Processing Record 4 of Set 6 | kazuno
# Processing Record 5 of Set 6 | calafell
# Processing Record 6 of Set 6 | dombarovskiy
# Processing Record 7 of Set 6 | sayyan
# Processing Record 8 of Set 6 | plettenberg bay
# Processing Record 9 of Set 6 | ossora
# Processing Record 10 of Set 6 | krasnogorsk
# Processing Record 11 of Set 6 | sisimiut
# Processing Record 12 of Set 6 | blonduos
# City not found. Skipping...
# Processing Record 13 of Set 6 | husavik
# Processing Record 14 of Set 6 | sao joao da barra
# Processing Record 15 of Set 6 | paamiut
# Processing Record 16 of Set 6 | stamsund
# City not found. Skipping...
# Processing Record 17 of Set 6 | kibondo
# Processing Record 18 of Set 6 | devils lake
# Processing Record 19 of Set 6 | lasa
# Processing Record 20 of Set 6 | saint-pierre
# Processing Record 21 of Set 6 | broken hill
# Processing Record 22 of Set 6 | vostok
# Processing Record 23 of Set 6 | atar
# Processing Record 24 of Set 6 | manokwari
# Processing Record 25 of Set 6 | huainan
# Processing Record 26 of Set 6 | bathurst
# Processing Record 27 of Set 6 | ngunguru
# Processing Record 28 of Set 6 | mikuni
# Processing Record 29 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 6 | fredericksburg
# Processing Record 31 of Set 6 | odate
# Processing Record 32 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 6 | loviisa
# Processing Record 34 of Set 6 | balkanabat
# Processing Record 35 of Set 6 | floresti
# Processing Record 36 of Set 6 | conceicao da barra
# Processing Record 37 of Set 6 | port hardy
# Processing Record 38 of Set 6 | jiexiu
# Processing Record 39 of Set 6 | pevek
# Processing Record 40 of Set 6 | natal
# Processing Record 41 of Set 6 | san ignacio
# Processing Record 42 of Set 6 | ventspils
# Processing Record 43 of Set 6 | brigantine
# Processing Record 44 of Set 6 | sefophe
# Processing Record 45 of Set 6 | iguatu
# Processing Record 46 of Set 6 | iskateley
# Processing Record 47 of Set 6 | arman
# Processing Record 48 of Set 6 | makakilo city
# Processing Record 49 of Set 6 | hasaki
# Processing Record 50 of Set 6 | bougouni
# Processing Record 1 of Set 7 | ugoofaaru
# Processing Record 2 of Set 7 | salym
# Processing Record 3 of Set 7 | culfa
# Processing Record 4 of Set 7 | elk city
# Processing Record 5 of Set 7 | vila velha
# Processing Record 6 of Set 7 | berani
# Processing Record 7 of Set 7 | petrozavodsk
# Processing Record 8 of Set 7 | kodiak
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | skibbereen
# Processing Record 11 of Set 7 | kushmurun
# Processing Record 12 of Set 7 | ilhabela
# Processing Record 13 of Set 7 | yulara
# Processing Record 14 of Set 7 | kaitangata
# Processing Record 15 of Set 7 | fort nelson
# Processing Record 16 of Set 7 | trelew
# Processing Record 17 of Set 7 | kawalu
# Processing Record 18 of Set 7 | grand baie
# Processing Record 19 of Set 7 | corning
# Processing Record 20 of Set 7 | montepuez
# Processing Record 21 of Set 7 | priiskovyy
# Processing Record 22 of Set 7 | aklavik
# Processing Record 23 of Set 7 | okhotsk
# Processing Record 24 of Set 7 | komsomolskiy
# Processing Record 25 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 26 of Set 7 | san patricio
# Processing Record 27 of Set 7 | sabha
# Processing Record 28 of Set 7 | necochea
# Processing Record 29 of Set 7 | longyearbyen
# Processing Record 30 of Set 7 | corinto
# Processing Record 31 of Set 7 | nanortalik
# Processing Record 32 of Set 7 | bundaberg
# Processing Record 33 of Set 7 | ixtapa
# Processing Record 34 of Set 7 | norman wells
# Processing Record 35 of Set 7 | seminole
# Processing Record 36 of Set 7 | basco
# Processing Record 37 of Set 7 | ville-marie
# Processing Record 38 of Set 7 | vila franca do campo
# Processing Record 39 of Set 7 | graham
# Processing Record 40 of Set 7 | marawi
# Processing Record 41 of Set 7 | magistralnyy
# Processing Record 42 of Set 7 | huoqiu
# Processing Record 43 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 44 of Set 7 | mogadishu
# Processing Record 45 of Set 7 | walvis bay
# Processing Record 46 of Set 7 | villa del rosario
# Processing Record 47 of Set 7 | kenai
# Processing Record 48 of Set 7 | zhigansk
# Processing Record 49 of Set 7 | kikwit
# Processing Record 50 of Set 7 | havre
# Processing Record 1 of Set 8 | rurrenabaque
# Processing Record 2 of Set 8 | tateyama
# Processing Record 3 of Set 8 | kavaratti
# Processing Record 4 of Set 8 | bara
# Processing Record 5 of Set 8 | korem
# Processing Record 6 of Set 8 | tongling
# Processing Record 7 of Set 8 | te anau
# Processing Record 8 of Set 8 | barsovo
# Processing Record 9 of Set 8 | hakkari
# Processing Record 10 of Set 8 | turan
# Processing Record 11 of Set 8 | kapit
# Processing Record 12 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 8 | kuminskiy
# Processing Record 14 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 8 | ridgecrest
# Processing Record 16 of Set 8 | hervey bay
# Processing Record 17 of Set 8 | lugovskiy
# City not found. Skipping...
# Processing Record 18 of Set 8 | ketchikan
# Processing Record 19 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 8 | mataram
# Processing Record 21 of Set 8 | lazaro cardenas
# Processing Record 22 of Set 8 | craig
# Processing Record 23 of Set 8 | nelson bay
# Processing Record 24 of Set 8 | tiksi
# Processing Record 25 of Set 8 | menongue
# Processing Record 26 of Set 8 | cape coast
# Processing Record 27 of Set 8 | mayumba
# Processing Record 28 of Set 8 | saint-augustin
# Processing Record 29 of Set 8 | agadez
# Processing Record 30 of Set 8 | funadhoo
# Processing Record 31 of Set 8 | santa marta de tormes
# Processing Record 32 of Set 8 | santa rosa
# Processing Record 33 of Set 8 | sibolga
# Processing Record 34 of Set 8 | ukiah
# Processing Record 35 of Set 8 | baker city
# Processing Record 36 of Set 8 | oranjemund
# Processing Record 37 of Set 8 | khatanga
# Processing Record 38 of Set 8 | les escoumins
# Processing Record 39 of Set 8 | flin flon
# Processing Record 40 of Set 8 | zhangjiakou
# Processing Record 41 of Set 8 | srednekolymsk
# Processing Record 42 of Set 8 | qaqortoq
# Processing Record 43 of Set 8 | stutterheim
# Processing Record 44 of Set 8 | ulan-ude
# Processing Record 45 of Set 8 | alofi
# Processing Record 46 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 8 | dingle
# Processing Record 48 of Set 8 | aybak
# City not found. Skipping...
# Processing Record 49 of Set 8 | altay
# Processing Record 50 of Set 8 | benguela
# Processing Record 1 of Set 9 | piracanjuba
# Processing Record 2 of Set 9 | eureka
# Processing Record 3 of Set 9 | goderich
# Processing Record 4 of Set 9 | baicheng
# Processing Record 5 of Set 9 | broome
# Processing Record 6 of Set 9 | cordoba
# Processing Record 7 of Set 9 | port-gentil
# Processing Record 8 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 9 | severomuysk
# Processing Record 10 of Set 9 | dauphin
# Processing Record 11 of Set 9 | yarmouth
# Processing Record 12 of Set 9 | karlskrona
# Processing Record 13 of Set 9 | victoria
# Processing Record 14 of Set 9 | taywarah
# Processing Record 15 of Set 9 | kirakira
# Processing Record 16 of Set 9 | anadyr
# Processing Record 17 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 9 | mwinilunga
# Processing Record 19 of Set 9 | binika
# Processing Record 20 of Set 9 | cardona
# Processing Record 21 of Set 9 | san vicente
# Processing Record 22 of Set 9 | teahupoo
# Processing Record 23 of Set 9 | alexandria
# Processing Record 24 of Set 9 | tazovskiy
# Processing Record 25 of Set 9 | padang
# Processing Record 26 of Set 9 | vammala
# Processing Record 27 of Set 9 | fallon
# Processing Record 28 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 9 | thompson
# Processing Record 30 of Set 9 | inirida
# Processing Record 31 of Set 9 | svobodnyy
# Processing Record 32 of Set 9 | phan thiet
# Processing Record 33 of Set 9 | grindavik
# Processing Record 34 of Set 9 | semporna
# Processing Record 35 of Set 9 | aksarka
# Processing Record 36 of Set 9 | chipinge
# Processing Record 37 of Set 9 | karaton
# Processing Record 38 of Set 9 | ondangwa
# Processing Record 39 of Set 9 | san cristobal
# Processing Record 40 of Set 9 | havoysund
# Processing Record 41 of Set 9 | la ronge
# Processing Record 42 of Set 9 | ust-kut
# Processing Record 43 of Set 9 | valera
# Processing Record 44 of Set 9 | djambala
# Processing Record 45 of Set 9 | high level
# Processing Record 46 of Set 9 | salisbury
# Processing Record 47 of Set 9 | praia da vitoria
# Processing Record 48 of Set 9 | codrington
# Processing Record 49 of Set 9 | rostovka
# Processing Record 50 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 2 of Set 10 | auki
# Processing Record 3 of Set 10 | sorland
# Processing Record 4 of Set 10 | yar-sale
# Processing Record 5 of Set 10 | kadirli
# Processing Record 6 of Set 10 | sola
# Processing Record 7 of Set 10 | kieta
# Processing Record 8 of Set 10 | pangnirtung
# Processing Record 9 of Set 10 | sao francisco do sul
# Processing Record 10 of Set 10 | launceston
# Processing Record 11 of Set 10 | trincomalee
# Processing Record 12 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 13 of Set 10 | vigrestad
# Processing Record 14 of Set 10 | lata
# Processing Record 15 of Set 10 | dunedin
# Processing Record 16 of Set 10 | ushirombo
# Processing Record 17 of Set 10 | kruisfontein
# Processing Record 18 of Set 10 | esperance
# Processing Record 19 of Set 10 | lavrentiya
# Processing Record 20 of Set 10 | luwuk
# Processing Record 21 of Set 10 | lincoln park
# Processing Record 22 of Set 10 | bonfim
# Processing Record 23 of Set 10 | kilindoni
# Processing Record 24 of Set 10 | maragogi
# Processing Record 25 of Set 10 | san pedro
# Processing Record 26 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 10 | labytnangi
# Processing Record 28 of Set 10 | ushtobe
# Processing Record 29 of Set 10 | araouane
# Processing Record 30 of Set 10 | port moresby
# Processing Record 31 of Set 10 | antalaha
# Processing Record 32 of Set 10 | chernenko
# Processing Record 33 of Set 10 | honningsvag
# Processing Record 34 of Set 10 | pastos bons
# Processing Record 35 of Set 10 | mount isa
# Processing Record 36 of Set 10 | youkounkoun
# Processing Record 37 of Set 10 | wasilla
# Processing Record 38 of Set 10 | birin
# Processing Record 39 of Set 10 | flinders
# Processing Record 40 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 10 | nyuksenitsa
# Processing Record 42 of Set 10 | acajutla
# Processing Record 43 of Set 10 | deputatskiy
# Processing Record 44 of Set 10 | san andres
# Processing Record 45 of Set 10 | becerril
# Processing Record 46 of Set 10 | hirado
# Processing Record 47 of Set 10 | port augusta
# Processing Record 48 of Set 10 | calabozo
# Processing Record 49 of Set 10 | sorong
# Processing Record 50 of Set 10 | great yarmouth
# Processing Record 1 of Set 11 | namibe
# Processing Record 2 of Set 11 | cayenne
# Processing Record 3 of Set 11 | staryy oskol
# Processing Record 4 of Set 11 | carevo
# City not found. Skipping...
# Processing Record 5 of Set 11 | kupang
# Processing Record 6 of Set 11 | aksu
# Processing Record 7 of Set 11 | ayia galini
# Processing Record 8 of Set 11 | narsaq
# Processing Record 9 of Set 11 | kichera
# Processing Record 10 of Set 11 | labuan
# Processing Record 11 of Set 11 | buta
# Processing Record 12 of Set 11 | pangkalanbuun
# Processing Record 13 of Set 11 | talcahuano
# Processing Record 14 of Set 11 | atambua
# Processing Record 15 of Set 11 | progreso
# Processing Record 16 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 11 | senanga
# Processing Record 18 of Set 11 | berlevag
# Processing Record 19 of Set 11 | ilmenau
# Processing Record 20 of Set 11 | hofu
# Processing Record 21 of Set 11 | kudahuvadhoo
# Processing Record 22 of Set 11 | yaan
# Processing Record 23 of Set 11 | airai
# Processing Record 24 of Set 11 | pozo colorado
# Processing Record 25 of Set 11 | chapleau
# Processing Record 26 of Set 11 | xadani
# City not found. Skipping...
# Processing Record 27 of Set 11 | avera
# Processing Record 28 of Set 11 | akyab
# Processing Record 29 of Set 11 | boden
# Processing Record 30 of Set 11 | borujan
# City not found. Skipping...
# Processing Record 31 of Set 11 | levelland
# Processing Record 32 of Set 11 | sungurlu
# Processing Record 33 of Set 11 | puertollano
# Processing Record 34 of Set 11 | mhlume
# Processing Record 35 of Set 11 | qena
# Processing Record 36 of Set 11 | pizarro
# Processing Record 37 of Set 11 | sehithwa
# Processing Record 38 of Set 11 | atlantic city
# Processing Record 39 of Set 11 | yuli
# Processing Record 40 of Set 11 | tiznit
# Processing Record 41 of Set 11 | bull savanna
# Processing Record 42 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 11 | olafsvik
# Processing Record 44 of Set 11 | caravelas
# Processing Record 45 of Set 11 | sao cristovao
# Processing Record 46 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 47 of Set 11 | tongchuan
# Processing Record 48 of Set 11 | fare
# Processing Record 49 of Set 11 | kafanchan
# Processing Record 50 of Set 11 | antofagasta
# Processing Record 1 of Set 12 | gryfino
# Processing Record 2 of Set 12 | nago
# Processing Record 3 of Set 12 | palmer
# Processing Record 4 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 5 of Set 12 | maniitsoq
# Processing Record 6 of Set 12 | timizart
# Processing Record 7 of Set 12 | inverell
# Processing Record 8 of Set 12 | roccastrada
# Processing Record 9 of Set 12 | cooma
# Processing Record 10 of Set 12 | batagay-alyta
# Processing Record 11 of Set 12 | jalu
# Processing Record 12 of Set 12 | moscow
# Processing Record 13 of Set 12 | thunder bay
# Processing Record 14 of Set 12 | inhambane
# Processing Record 15 of Set 12 | vyshestebliyevskaya
# Processing Record 16 of Set 12 | moerai
# Processing Record 17 of Set 12 | khanpur
# Processing Record 18 of Set 12 | muros
# Processing Record 19 of Set 12 | roald
# Processing Record 20 of Set 12 | staroaleyskoye
# Processing Record 21 of Set 12 | ilulissat
# Processing Record 22 of Set 12 | fortuna foothills
# Processing Record 23 of Set 12 | yerofey pavlovich
# Processing Record 24 of Set 12 | qui nhon
# Processing Record 25 of Set 12 | dolores
# Processing Record 26 of Set 12 | baruun-urt
# Processing Record 27 of Set 12 | chai nat
# Processing Record 28 of Set 12 | xam nua
# Processing Record 29 of Set 12 | morant bay
# Processing Record 30 of Set 12 | gushikawa
# Processing Record 31 of Set 12 | berezovyy
# Processing Record 32 of Set 12 | hofn
# Processing Record 33 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 12 | svetlogorsk
# Processing Record 35 of Set 12 | tahta
# Processing Record 36 of Set 12 | nuzvid
# Processing Record 37 of Set 12 | taltal
# Processing Record 38 of Set 12 | doka
# Processing Record 39 of Set 12 | labuhan
# Processing Record 40 of Set 12 | puerto ayacucho
# Processing Record 41 of Set 12 | santa fe
# Processing Record 42 of Set 12 | casper
# Processing Record 43 of Set 12 | beyneu
# Processing Record 44 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 12 | el wasta
# City not found. Skipping...
# Processing Record 46 of Set 12 | usinsk
# Processing Record 47 of Set 12 | axim
# Processing Record 48 of Set 12 | champerico
# Processing Record 49 of Set 12 | biltine
# Processing Record 50 of Set 12 | novikovo
# Processing Record 1 of Set 13 | cockburn town
# Processing Record 2 of Set 13 | toulepleu
# City not found. Skipping...
# Processing Record 3 of Set 13 | warrington
# Processing Record 4 of Set 13 | haines junction
# Processing Record 5 of Set 13 | aginskoye
# Processing Record 6 of Set 13 | dhing
# Processing Record 7 of Set 13 | markala
# Processing Record 8 of Set 13 | kijang
# Processing Record 9 of Set 13 | kaabong
# Processing Record 10 of Set 13 | talavera
# Processing Record 11 of Set 13 | kizukuri
# Processing Record 12 of Set 13 | matadi
# Processing Record 13 of Set 13 | jumla
# Processing Record 14 of Set 13 | jijiga
# Processing Record 15 of Set 13 | peru
# Processing Record 16 of Set 13 | yermakovskoye
# Processing Record 17 of Set 13 | adrar
# Processing Record 18 of Set 13 | urucara
# Processing Record 19 of Set 13 | ialibu
# Processing Record 20 of Set 13 | amapa
# Processing Record 21 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 22 of Set 13 | sheffield
# Processing Record 23 of Set 13 | gizo
# Processing Record 24 of Set 13 | karratha
# Processing Record 25 of Set 13 | comodoro rivadavia
# Processing Record 26 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 13 | verkhoyansk
# Processing Record 28 of Set 13 | vila
# Processing Record 29 of Set 13 | da nang
# Processing Record 30 of Set 13 | ust-omchug
# Processing Record 31 of Set 13 | alta floresta
# Processing Record 32 of Set 13 | do rud
# City not found. Skipping...
# Processing Record 33 of Set 13 | neiafu
# Processing Record 34 of Set 13 | taburbah
# City not found. Skipping...
# Processing Record 35 of Set 13 | xining
# Processing Record 36 of Set 13 | villarrica
# Processing Record 37 of Set 13 | angoram
# Processing Record 38 of Set 13 | prince rupert
# Processing Record 39 of Set 13 | nador
# Processing Record 40 of Set 13 | ngama
# Processing Record 41 of Set 13 | rucheng
# Processing Record 42 of Set 13 | ust-maya
# Processing Record 43 of Set 13 | vytegra
# Processing Record 44 of Set 13 | emerald
# Processing Record 45 of Set 13 | atbasar
# Processing Record 46 of Set 13 | safaqis
# City not found. Skipping...
# Processing Record 47 of Set 13 | nhulunbuy
# Processing Record 48 of Set 13 | caldelas
# Processing Record 49 of Set 13 | umm lajj
# Processing Record 50 of Set 13 | winchester
# Processing Record 1 of Set 14 | pringsewu
# Processing Record 2 of Set 14 | jining
# Processing Record 3 of Set 14 | huescar
# Processing Record 4 of Set 14 | ihosy
# Processing Record 5 of Set 14 | stilfontein
# Processing Record 6 of Set 14 | chardara
# Processing Record 7 of Set 14 | puri
# Processing Record 8 of Set 14 | damara
# Processing Record 9 of Set 14 | kjollefjord
# Processing Record 10 of Set 14 | gladstone
# Processing Record 11 of Set 14 | barkhera
# Processing Record 12 of Set 14 | columbus
# Processing Record 13 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 14 | chegem
# Processing Record 15 of Set 14 | kozhva
# Processing Record 16 of Set 14 | moanda
# Processing Record 17 of Set 14 | rawdon
# Processing Record 18 of Set 14 | payson
# Processing Record 19 of Set 14 | grimshaw
# Processing Record 20 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 14 | bambanglipuro
# Processing Record 22 of Set 14 | puerto narino
# Processing Record 23 of Set 14 | majene
# Processing Record 24 of Set 14 | roebourne
# Processing Record 25 of Set 14 | merrill
# Processing Record 26 of Set 14 | mackenzie
# Processing Record 27 of Set 14 | guerrero negro
# Processing Record 28 of Set 14 | terney
# Processing Record 29 of Set 14 | nicoya
# Processing Record 30 of Set 14 | pangai
# Processing Record 31 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 32 of Set 14 | daru
# Processing Record 33 of Set 14 | shenjiamen
# Processing Record 34 of Set 14 | pembroke
# Processing Record 35 of Set 14 | big spring
# Processing Record 36 of Set 14 | kade
# Processing Record 37 of Set 14 | srandakan
# Processing Record 38 of Set 14 | muisne
# Processing Record 39 of Set 14 | erdenet
# Processing Record 40 of Set 14 | senno
# Processing Record 41 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 14 | bawku
# Processing Record 43 of Set 14 | shizuishan
# Processing Record 44 of Set 14 | edmonds
# Processing Record 45 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 14 | macklin
# Processing Record 47 of Set 14 | dickinson
# Processing Record 48 of Set 14 | senador jose porfirio
# Processing Record 49 of Set 14 | kalnibolotskaya
# Processing Record 50 of Set 14 | palma
# Processing Record 1 of Set 15 | cabinda
# Processing Record 2 of Set 15 | swan river
# Processing Record 3 of Set 15 | sandviken
# Processing Record 4 of Set 15 | san isidro
# Processing Record 5 of Set 15 | guadalupe y calvo
# Processing Record 6 of Set 15 | opuwo
# Processing Record 7 of Set 15 | keetmanshoop
# Processing Record 8 of Set 15 | faanui
# Processing Record 9 of Set 15 | harper
# Processing Record 10 of Set 15 | sri aman
# Processing Record 11 of Set 15 | grand gaube
# Processing Record 12 of Set 15 | jilikul
# Processing Record 13 of Set 15 | aykhal
# Processing Record 14 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 15 of Set 15 | kendari
# Processing Record 16 of Set 15 | cosamaloapan
# Processing Record 17 of Set 15 | gobabis
# Processing Record 18 of Set 15 | yumen
# Processing Record 19 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 15 | malavalli
# Processing Record 21 of Set 15 | ahuimanu
# Processing Record 22 of Set 15 | zhumadian
# Processing Record 23 of Set 15 | ucluelet
# Processing Record 24 of Set 15 | almaznyy
# Processing Record 25 of Set 15 | shelburne
# Processing Record 26 of Set 15 | rouvroy
# Processing Record 27 of Set 15 | knysna
# Processing Record 28 of Set 15 | tuatapere
# Processing Record 29 of Set 15 | richards bay
# Processing Record 30 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 31 of Set 15 | zenzeli
# Processing Record 32 of Set 15 | malgrat de mar
# Processing Record 33 of Set 15 | zhuzhou
# Processing Record 34 of Set 15 | cocorit
# Processing Record 35 of Set 15 | kushiro
# Processing Record 36 of Set 15 | hamilton
# Processing Record 37 of Set 15 | maraa
# Processing Record 38 of Set 15 | khasan
# Processing Record 39 of Set 15 | gracac
# Processing Record 40 of Set 15 | buchanan
# Processing Record 41 of Set 15 | hue
# Processing Record 42 of Set 15 | porto walter
# Processing Record 43 of Set 15 | noumea
# Processing Record 44 of Set 15 | fairview
# Processing Record 45 of Set 15 | cortes
# Processing Record 46 of Set 15 | pogar
# Processing Record 47 of Set 15 | buala
# Processing Record 48 of Set 15 | okha
# Processing Record 49 of Set 15 | pampas
# Processing Record 50 of Set 15 | nizwa
# Processing Record 1 of Set 16 | nueva loja
# Processing Record 2 of Set 16 | bowen
# Processing Record 3 of Set 16 | salta
# Processing Record 4 of Set 16 | sobolevo
# Processing Record 5 of Set 16 | jiroft
# City not found. Skipping...
# Processing Record 6 of Set 16 | mazamari
# Processing Record 7 of Set 16 | youghal
# Processing Record 8 of Set 16 | stege
# Processing Record 9 of Set 16 | verkhnevilyuysk
# Processing Record 10 of Set 16 | milevsko
# Processing Record 11 of Set 16 | balabac
# Processing Record 12 of Set 16 | norilsk
# Processing Record 13 of Set 16 | mehamn
# Processing Record 14 of Set 16 | daura
# Processing Record 15 of Set 16 | great bend
# Processing Record 16 of Set 16 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 16 | oktyabrskiy
# Processing Record 18 of Set 16 | mimongo
# Processing Record 19 of Set 16 | hammerfest
# Processing Record 20 of Set 16 | raytown
# Processing Record 21 of Set 16 | polunochnoye
# Processing Record 22 of Set 16 | gurupa
# Processing Record 23 of Set 16 | tautira
# Processing Record 24 of Set 16 | taoudenni
# Processing Record 25 of Set 16 | thinadhoo
# Processing Record 26 of Set 16 | boysun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Port Alfred      ZA -33.5906   26.8910     65.19        87           6
# 1      San Quintin      MX  30.4833 -115.9500     68.13        73           0
# 2      Kloulklubed      PW   7.0419  134.2556     79.30        79         100
# 3      New Norfolk      AU -42.7826  147.0587     51.93        61          66
# 4             Chuy      UY -33.6971  -53.4616     72.32        72          99
# 5        Ostrovnoy      RU  68.0531   39.5131     31.91        84          97
# 6             Hilo      US  19.7297 -155.0900     82.27        68           1
# 7       Chokurdakh      RU  70.6333  147.9167     -5.58        98          99
# 8  Charters Towers      AU -20.1000  146.2667     72.05        82           3
# 9            Vaini      TO -21.2000 -175.2000     71.76        94          20
#
#    Wind Speed Current Descrption
# 0       12.62          clear sky
# 1        6.13          clear sky
# 2       14.00         light rain
# 3        3.00      broken clouds
# 4       13.04    overcast clouds
# 5       10.22    overcast clouds
# 6        5.75          clear sky
# 7        6.17    overcast clouds
# 8        7.29          clear sky
# 9        3.44         few clouds

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(r'C:/Users/maria/Desktop/Classwork/World_Weather_Analysis/Weateher_database/WeatherPy_Database.csv', index_label="City_id")
